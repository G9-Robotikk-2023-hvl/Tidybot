# %%
from spatialmath import SO3, SE3
R1 = SO3.Rx(0.3)
R1
# Out:
#    1         0         0
#    0         0.9553   -0.2955
#    0         0.2955    0.9553

# %%
from spatialmath import SO3, SE3
from numpy import pi

SE3.Rx(0*pi/180).plot()
(SE3.Rx(60*pi/180)).plot(color="red")
(SE3.Rx(60*pi/180)*SE3.Rz(60*pi/180)*SE3).plot(color="green")

# %%
from spatialmath import SO3, SE3
from roboticstoolbox import DHLink, DHRobot, RevoluteDH
from numpy import pi, cos as c, sin as s

robot = DHRobot.URDF(file_path="demo.urdf")

display(robot)

# robot.plot([pi,0,0,0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\GIT_Repositories\Tidybot\notes\Python-robotics-toolbox.ipynb Cell 3 line 5
#       <a href='vscode-notebook-cell:/d%3A/GIT_Repositories/Tidybot/notes/Python-robotics-toolbox.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> from roboticstoolbox import DHLink, DHRobot, RevoluteDH
#       <a href='vscode-notebook-cell:/d%3A/GIT_Repositories/Tidybot/notes/Python-robotics-toolbox.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> from numpy import pi, cos as c, sin as s
# ----> <a href='vscode-notebook-cell:/d%3A/GIT_Repositories/Tidybot/notes/Python-robotics-toolbox.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> robot = DHRobot.URDF(file_path="demo.urdf")
#       <a href='vscode-notebook-cell:/d%3A/GIT_Repositories/Tidybot/notes/Python-robotics-toolbox.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> display(robot)
# ...

# %%
#!/usr/bin/env python
"""
@author Jesse Haviland
"""

import roboticstoolbox as rtb

# Make a panda robot
panda = rtb.models.DH.Panda()

# Init joint to the 'ready' joint angles
panda.q = panda.qr

# Open a plot with the teach panel
#e = panda.teach(panda.q)
display(panda)
# Out:
# DHRobot: Panda (by Franka Emika), 7 joints (RRRRRRR), dynamics, geometry, modified DH parameters
# ┌────────┬────────┬─────┬───────┬─────────┬────────┐
# │ aⱼ₋₁   │  ⍺ⱼ₋₁  │ θⱼ  │  dⱼ   │   q⁻    │   q⁺   │
# ├────────┼────────┼─────┼───────┼─────────┼────────┤
# │    0.0 │   0.0° │  q1 │ 0.333 │ -166.0° │ 166.0° │
# │    0.0 │ -90.0° │  q2 │   0.0 │ -101.0° │ 101.0° │
# │    0.0 │  90.0° │  q3 │ 0.316 │ -166.0° │ 166.0° │
# │ 0.0825 │  90.0° │  q4 │   0.0 │ -176.0° │  -4.0° │
# │-0.0825 │ -90.0° │  q5 │ 0.384 │ -166.0° │ 166.0° │
# │    0.0 │  90.0° │  q6 │   0.0 │   -1.0° │ 215.0° │
# │  0.088 │  90.0° │  q7 │ 0.107 │ -166.0° │ 166.0° │
# └────────┴────────┴─────┴───────┴─────────┴────────┘
#
# ┌─────┬───────────────────────────────────────┐
# │tool │ t = 0, 0, 0.1; rpy/xyz = -45°, 0°, 0° │
# └─────┴───────────────────────────────────────┘
#
# ┌─────┬─────┬────────┬─────┬───────┬─────┬───────┬──────┐
# │name │ q0  │ q1     │ q2  │ q3    │ q4  │ q5    │ q6   │
# ...
